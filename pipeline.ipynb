# %%
from pipeline.main import process_video

# %%
# %load_ext autoreload
# %autoreload 2

# %%
process_video(
    model_path=".\models\patchcore\checkpoints\patchcore-project\patchcore-group\models\paperclips_front",
    video_path=".\data\inference vid2.MOV",
    openai_api_key="###"
    medium_threshold=5.5,
    high_threshold=6,
    object_threshold=0.2,
    playback_speed=1, 
    system_prompt="You are an expert in paperclip manufacturing quality control. Analyze the image showing a paperclip and its corresponding anomaly heatmap.Focus on: 1. Identifying specific defects (bends, gaps, twists, surface defects)2. Describing the location and severity of any anomalies 3. Determining if the paperclip meets quality standards 4. Suggesting possible causes for the defects Respond in plain text with a concise, technical analysis describing precisely what defects you observe and their significance. Be specific about which parts of the paperclip show anomalies, using clear directional terms.Do not include any markdown formatting, lists, or headings in your response.",
    enable_gpt4=False,
    disable_video_display=False,
    use_camera=False,
    camera_index=0,
    process_every_n_frames=5,
    detection_area_ratio=.2
)
# Out:
# HTML(value='Initializing...', layout=Layout(border_bottom='1px solid #444', border_left='1px solid #444', bord…
# ...
# Output()
# models loaded
# queues created
# anomaly detection thread started
# test waiting for frame
#  GPT worker starting
#  Testing API connection...
# result thread started
# Test response: 200
# API connection verified
# test waiting for frame
# [INFO] Method used: yolo
# Processing frame 200
# test waiting for frame
# Processing frame 200
# Encoded image (48048 chars)
# Sending request to OpenAI API...
# [INFO] Method used: edge_detection
# Processing frame 390
# test waiting for frame
# Successfully processed frame 200
# Processing frame 390
# Encoded image (47388 chars)
# Sending request to OpenAI API...
# Updated GPT result for frame 200
# [INFO] Method used: yolo
# Processing frame 620
# test waiting for frame
# Successfully processed frame 390
# Processing frame 620
# Updated GPT result for frame 390
# [INFO] Method used: yolo
# Processing frame 830
# ...
